# %% [markdown]
# <a href="https://colab.research.google.com/github/ukw1014/MyApplication/blob/master/total.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import random
import time


def get_context(Profession_id):
    text = "&"
    if Profession_id == 1:
          text = text + "brew"
          return text
    elif Profession_id == 2:
          text = text + "farm"
          return text
    elif Profession_id == 3:
          context_list = [
            "&fell",
            "&FELL",
            "&wood",
            "&hew",
          ]
          text = random.choice(context_list)
          return text
    elif Profession_id == 4:
          text = text + "fish"
          return text
    elif Profession_id == 5:
          text = text + "herd"
          return text
    elif Profession_id == 6:
          text = text + "mine"
          return text
    else:
          return "判別身份失敗了ㄛQAQ"


def chat(chanel_list,authorization_list,Profession_id):
    for authorization in authorization_list:
        header = {
            "Authorization": authorization,
            "Content-Type": "application/json",
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36",
        }
        for chanel_id in chanel_list:
            msg = {
                "content": get_context(Profession_id),
                "nonce": "82329451214{}33232234".format(random.randrange(0, 1000)),
                "tts": False,
            }
            url = "https://discord.com/api/v9/channels/{}/messages".format(chanel_id)
            try:
                res = requests.post(url=url, headers=header, data=json.dumps(msg))
                print(res.content)
            except:
                pass
            continue
        time.sleep(random.randrange(1, 3))


if __name__ == "__main__":
    chanel_list = ["983800063228788777"]
    chanel_list2 = ["983679916308574209"]
    chanel_list3 = ["981057712169312287"]
    kProfession_id = 5
    kProfession_id2 = 4
    kProfession_id3 = 6
    kProfession_id4 = 2
    kProfession_id5 = 1
    kProfession_id6 = 3
    Profession_id狐娘賽高 = 6
    Profession_id呱呱 = 5
    Profession_idD3神者 = 6
    Profession_id像極了愛情 = 5
    Profession_id海咪寶寶 = 5
    Profession_id我不知道我名字 = 1
    Profession_idZakeru = 4
    Profession_id拿鐵好喝 = 4
    Profession_idNekoNeko = 5
    Profession_idEternalBear = 6
    Profession_idEternalCuteBear = 4
    Profession_idEternalNekoNeko = 3
    Profession_idEternalNekoCuteBear = 6
    Profession_idNekoCat = 6
    Profession_idLonelyNeko = 6
    Profession_idSnowCat = 2
    Profession_idSnowbear = 2
    Profession_idSnowDog = 6
    Profession_idSnowFish = 6
    Profession_idSnowPig = 5
    Profession_idAtnx = 6
    Profession_idA1B47 = 6
    Profession_idAsqwe = 6
    Profession_idQWAC = 6
    Profession_idHappyBear = 6
    authorization = ["OTc4NzEwNTc5NDQ5NTc3NDgy.G53LT5.XGEj2dbQOeIvnHPQQ-VsJp7AGznGgfwr9OoWEk"]
    authorization1 = ["OTc4OTIyNDI3MTAwODIzNTcz.GaYRdi.68nKa4RMkfK6wOmJS5GP2TuKCZPNLkI3noHg6Y"]
    authorization2 = ["OTQzMjMwMDMwMDE0NzMwMjQw.G_AnNP.HU9qb1Hd-oifruVPh7q7ZYEiu141yDTxps5dhk"]
    authorization3 = ["OTc0NjkwNzE2OTgwNzQwMTI2.GChHV8.U5hcKmXPWxODMYPU4qwAL4oU7Kgq6utLyk5SwE"]
    authorization4 = ["OTg0NTA2NjgzMzY1Njg3MzI2.G1xPbn.jLNnMwO06g3JM-IliDaXfv-Gku-j01mtJHcdN8"]
    authorization_listSnowbear = ["OTk5MzYzNjI3MTI5NzY1OTc5.G9_kK0.-QxLxQR_9x9aI0gXrtJmw2VtMRNAU19nqEgsgY"]
    authorization_listSnowDog = ["OTk5NjMwNzY0MTQyNTA2MDE0.GcN5pc.QdMMtfjuoyC1cvnXsTH3Yz7f-_ki-nCwEqZrIU"]
    authorization_listSnowFish = ["OTk5NjM0Nzc4ODI1NDI0OTE2.GcQZ8B.KzKu5zEvbyjmSrel__JTK36si26jWauFS6p6KE"]
    authorization_listSnowPig = ["OTk5NjM3NTY1OTYxNDIwODgx.Gu3dmp.yFBAqgFlKHgc_5AWqjZCBjCbTNcvGcaQBiIUAs"]
    authorization_listAtnx = ["OTk5OTcyMzYwOTk4MzU5MDQx.Gzyf9a.218OUMnfTzeqGks3LmkYMFj53oH8Xmf6wY36_k"]
    authorization_listA1B47 = ["MTAwMDA4NDQ4ODMwNDQ2ODAwOA.GsltPC.O7WJVxCqZnQqGysiGzbFgyvcrtOpBUJh-1pcQM"]
    authorization_listAsqwe = ["MTAwMDA4NzYzNjAzMzE2MzMyNQ.GLDHQq.7AW4FhfsE9YlEFIdL8bEnsnYz4GzOdNrEPTYWg"]
    authorization_listQWAC = ["MTAwMDQ3MTUzODU5Nzg5NjI1Mg.GpsQXS.Fl9F2WjubK9h3gebKAfo89h3psmbRyGEgSJjO0"]
    authorization_listHappyBear = ["MTAwMDQ3MjI4Mjk5NDU3MzM5NQ.GBKjgh.xA8Mn8RO8iD3PQGbK4_gfZ3vfbtPo162fiNV-w"]
    while True:
        try:
            chat(chanel_list3,authorization,kProfession_id3)
            chat(chanel_list3,authorization1,kProfession_id)
            chat(chanel_list3,authorization2,kProfession_id)
            chat(chanel_list3,authorization3,kProfession_id3)
            chat(chanel_list3,authorization4,kProfession_id)
            chat(chanel_list3,authorization5,kProfession_id3)
            chat(chanel_list3,authorization6,kProfession_id3)
            chat(chanel_list3,authorization7,kProfession_id3) 
            chat(chanel_list3,authorization8,kProfession_id3)
            chat(chanel_list3,authorization9,kProfession_id3)
            chat(chanel_list3,authorization10,kProfession_id3)
            chat(chanel_list3,authorization11,kProfession_id3)
            chat(chanel_list2,kauthorization_list1,kProfession_id)
            chat(chanel_list2,kauthorization_list2,kProfession_id)
            chat(chanel_list2,kauthorization_list3,kProfession_id)
            chat(chanel_list2,kauthorization_list4,kProfession_id2)
            chat(chanel_list2,kauthorization_list5,kProfession_id2)
            chat(chanel_list2,kauthorization_list6,kProfession_id)
            chat(chanel_list2,kauthorization_list7,kProfession_id)
            chat(chanel_list2,kauthorization_list8,kProfession_id2)
            chat(chanel_list2,kauthorization_list9,kProfession_id3)
            chat(chanel_list2,kauthorization_list10,kProfession_id)
            chat(chanel_list2,kauthorization_list11,kProfession_id3)
            chat(chanel_list2,kauthorization_list12,kProfession_id3)
            chat(chanel_list2,kauthorization_list13,kProfession_id3)
            chat(chanel_list2,kauthorization_list14,kProfession_id3)
            chat(chanel_list2,kauthorization_list15,kProfession_id)
            chat(chanel_list2,kauthorization_list16,kProfession_id)
            chat(chanel_list2,kauthorization_list17,kProfession_id)
            chat(chanel_list2,kauthorization_list18,kProfession_id4)
            chat(chanel_list2,kauthorization_list19,kProfession_id4)
            chat(chanel_list2,kauthorization_list20,kProfession_id)
            chat(chanel_list2,kauthorization_list21,kProfession_id)
            chat(chanel_list2,kauthorization_list22,kProfession_id)
            chat(chanel_list2,kauthorization_list23,kProfession_id)
            chat(chanel_list2,kauthorization_list24,kProfession_id)
            chat(chanel_list2,kauthorization_list25,kProfession_id3)
            chat(chanel_list2,kauthorization_list26,kProfession_id3)
            chat(chanel_list2,kauthorization_list27,kProfession_id3)
            chat(chanel_list2,kauthorization_list28,kProfession_id3)
            chat(chanel_list2,kauthorization_list29,kProfession_id5)
            chat(chanel_list2,kauthorization_list30,kProfession_id6)
            chat(chanel_list,authorization_list狐娘賽高,Profession_id狐娘賽高)
            chat(chanel_list,authorization_list呱呱,Profession_id呱呱)
            chat(chanel_list,authorization_listD3神者,Profession_idD3神者)
            chat(chanel_list,authorization_list像極了愛情,Profession_id像極了愛情)
            chat(chanel_list,authorization_list海咪寶寶,Profession_id海咪寶寶)
            chat(chanel_list,authorization_list我不知道我名字,Profession_id我不知道我名字)
            chat(chanel_list,authorization_listZakeru,Profession_idZakeru)
            chat(chanel_list,authorization_list拿鐵好喝,Profession_id拿鐵好喝)
            chat(chanel_list,authorization_listNekoNeko,Profession_idNekoNeko)
            chat(chanel_list,authorization_listEternalBear,Profession_idEternalBear)
            chat(chanel_list,authorization_listEternalCuteBear,Profession_idEternalCuteBear)
            chat(chanel_list,authorization_listEternalNekoNeko,Profession_idEternalNekoNeko)
            chat(chanel_list,authorization_listEternalNekoCuteBear,Profession_idEternalNekoCuteBear)
            chat(chanel_list,authorization_listNekoCat,Profession_idNekoCat)
            chat(chanel_list,authorization_listLonelyNeko,Profession_idLonelyNeko)
            chat(chanel_list,authorization_listSnowCat,Profession_idSnowCat)
            chat(chanel_list,authorization_listSnowbear,Profession_idSnowbear)
            chat(chanel_list,authorization_listSnowDog,Profession_idSnowDog)
            chat(chanel_list,authorization_listSnowFish,Profession_idSnowFish)
            chat(chanel_list,authorization_listSnowPig,Profession_idSnowPig)
            chat(chanel_list,authorization_listAtnx,Profession_idAtnx)
            chat(chanel_list,authorization_listA1B47,Profession_idA1B47)
            chat(chanel_list,authorization_listAsqwe,Profession_idAsqwe)
            chat(chanel_list,authorization_listQWAC,Profession_idQWAC)
            chat(chanel_list,authorization_listHappyBear,Profession_idHappyBear)
            time.sleep(random.randrange(1, 420))
            
        except:
            break
# Out:
# b'{"id": "1013119799783591986", "type": 0, "content": "&mine", "channel_id": "981057712169312287", "author": {"id": "978710579449577482", "username": "DD", "avatar": "190fb551c332df071ef9be7885f22fbb", "avatar_decoration": null, "discriminator": "8294", "public_flags": 0}, "attachments": [], "embeds": [], "mentions": [], "mention_roles": [], "pinned": false, "mention_everyone": false, "tts": false, "timestamp": "2022-08-27T16:16:23.124000+00:00", "edited_timestamp": null, "flags": 0, "components": [], "nonce": "8232945121488133232234", "referenced_message": null}'
# ...
